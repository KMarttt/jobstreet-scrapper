# %%
import jd_skills
import matplotlib.pyplot as plt
import importlib

# %%
importlib.reload(jd_skills)
skill_set = jd_skills.get_skills()


for phrase, count in skill_set.most_common(80):
        print(f"{phrase}: {count}")
# Out:
# Strong: 40
# Power BI: 38
# SQL: 30
# Experience: 29
# Bachelor: 28
# Tableau: 28
# AI: 23
# IT: 21
# Computer Science: 21
# English: 20
# Excel: 18
# Statistics: 17
# Python: 17
# Collaborate: 16
# Thai: 16
# We: 16
# Job: 16
# Ability: 15
# BI: 15
# Excellent: 14
# Qualifications: 14
# Develop: 13
# Work: 13
# Responsibilities: 12
# Provide: 12
# This: 12
# Design: 11
# The: 11
# You: 11
# Master: 11
# Analyze: 10
# Proficiency: 10
# Ensure: 10
# Support: 10
# Monitor: 9
# Good: 9
# Mathematics: 9
# Microsoft Excel: 9
# Minimum: 9
# Qualification: 8
# Manage: 8
# Data: 8
# Engineering: 8
# Computer Engineering: 8
# Proficient: 8
# Business: 8
# Identify: 8
# Familiarity: 8
# Degree: 8
# Finance: 8
# SAP: 8
# Prepare: 7
# Marketing: 7
# Economics: 7
# Knowledge: 7
# Conduct: 7
# Create: 7
# Business Administration: 7
# Understand: 7
# Key Responsibilities: 7
# Coordinate: 7
# ML: 7
# Be: 7
# Supervise: 7
# Data Science: 7
# Data Analytics: 6
# Thailand: 6
# Our: 6
# Advanced: 6
# ...

# %%
top_skills = dict(skill_set.most_common(50))

plt.figure(figsize=(10, 5))
plt.bar(top_skills.keys(), top_skills.values(), color='lightgreen')
plt.title("Top 10 Capitalized Skills from Job Descriptions")
plt.xlabel("Skill")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
