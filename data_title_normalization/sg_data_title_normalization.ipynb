# %% [markdown]
# **Data Normalization & Dupe Remover for Singapore Data**

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (0.17.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (2.3.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (2.11.7)
# Requirement already satisfied: jinja2 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.7.14)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.0.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.22.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.3.0.post1)
# Requirement already satisfied: wrapt in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\marti\documents\files\codes\python\web scraping\try-jobstreet-scraping\.venv\lib\site-packages (from jinja2->spacy) (3.0.2)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------- ------------------------------ 2.9/12.8 MB 15.1 MB/s eta 0:00:01
#      ------------- -------------------------- 4.5/12.8 MB 11.5 MB/s eta 0:00:01
#      ------------------- -------------------- 6.3/12.8 MB 10.2 MB/s eta 0:00:01
#      ----------------------- ---------------- 7.6/12.8 MB 9.4 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.2/12.8 MB 8.9 MB/s eta 0:00:01
#      -------------------------------- ------- 10.5/12.8 MB 8.8 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 8.6 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 8.5 MB/s  0:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import pandas as pd
import glob
import re

# %%
import spacy

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

# %%
# Combine All of the data into a unified whole

country = "Thailand"

all_files = glob.glob(f"../data/{country}_Job-Listing/*.csv")

dfs = []
for file in all_files:
    df = pd.read_csv(file)

    # extract keyword from filename
    keyword = file.split("__")[1].replace("_final", "").replace(".csv", "").replace("-", " ")

    df["search_keyword"] = keyword.lower()
    df["source_file"] = file
    dfs.append(df)

combined_df = pd.concat(dfs, ignore_index=True)

# %%
# combined_df.tail(10)

# %%
combined_df["search_keyword"].value_counts()
# Out:
# search_keyword
# data analyst                          1706
# data scientist                         885
# data engineer                          627
# sql developer                          624
# machine learning engineer              347
# ai strategist                          266
# analytics consultant                   199
# ai researcher                          182
# deep learning engineer                 181
# data science consultant                181
# power bi analyst                       170
# tableau developer                      164
# data product manager                   158
# business intelligence analyst          131
# ai engineer                            126
# data architect                         114
# nlp engineer                           101
# artificial intelligence specialist      90
# data driven decision maker              78
# generative ai developer                 72
# ai product manager                      42
# computer vision specialist              42
# data strategy consultant                34
# Name: count, dtype: int64

# %%
abbr_dict = {
    "ai": {"artificial", "intelligence"},
    "ml": {"machine",  "learn"},
    "nlp": {"natural",  "language", "process"},
    "qa": {"quality",  "assurance"},
    "swe": {"software", "engineer"},
    "llm": {"large", "language", "model"},
    "cybersecurity": {"cyber", "security"},
    
    
}

job_title_mapping = {
    "ai engineer": {
        "alternatives": [
            {
                "required": {"artificial", "intelligence"},
                "any_of": {"engineer", "developer", "architect"},
            }
        ]  
    },
    "ai product manager": {"artificial", "intelligence", "product", "manager"},
    "ai researcher": {
        "alternatives": [
            {
                "required": {"artificial", "intelligence"},
                "any_of": {"science", "research"},
            },
            {
                "required": {"machine", "learning"},
                "any_of": {"science", "research"},
            },
            {
                "required": {"large", "model"},
                "any_of": {"science", "research"},
            },
            # large, language, model
            {
                "required": {"nlp"},
                "any_of": {"science", "research"},
            },
            {
                "required": {"genai"},
                "any_of": {"science", "research"},
            }
        ]
        
    },
    "ai strategist": {
        "alternatives": [
            {
                "required": {"artificial", "intelligence"},
                "any_of": {"strategy", "governance", "planning"}
            },
            {
                "required": {"artificial", "intelligence", "risk", "management"},
            }
        ]
    },
    "artificial intelligence specialist": {"artificial", "intelligence", "specialist"},
    "analytics consultant": {"analytics", "consultant"},
    "business intelligence analyst": {
        "required": {"business", "intelligence"},
        "any_of": {"analyst", "specialist"},
    },
    "data analyst": {
        "required": {"data"},
        "any_of": {"analytics", "analyst", "specialist"},
        # intelligence
    },
    "data architect": {"data", "architect"},
    "data driven decision maker": {"data", "driven", "decision", "maker"},
    "data engineer": {
        "alternatives": [
            {
                "required": {"data"},
                "any_of": {"engineer", "modeler"}
            },
            {
                "required": {"data", "platform"},
                "any_of": {"engineer", "modeler", "developer"}
            },
            {
                "required": {"data", "warehouse"},
                "any_of": {"engineer", "modeler", "developer"}
            },
            {
                "required": {"ETL"},
                "any_of": {"engineer", "modeler", "developer"}
            }

        ]
        
    },
    "data product manager": {
        "alternatives": [
            {
                "required": {"data", "product"},
                "any_of": {"manager", "director"},
            },
            {
                "required": {"data", "project"},
                "any_of": {"manager", "director"},
            }
        ]
    },
    
    # "data research": {"data", "research"},
    "data science consultant": {"data", "science", "consultant"},
    "data scientist": {"data", "science"},
    "data strategy consultant": {"data", "strategy"},
    "data visualization": {
        "alternatives": [
            {
                "required": {"data", "visualization"},
                "any_of": {"visualization", "analyst", "tool", "developer", "specialist"}
            },
            {
                "required": {"power", "bi"},
                "any_of": {"visualization", "analyst", "tool", "developer", "specialist"}
            },
            {
                "required": {"tableau"},
                "any_of": {"visualization", "analyst", "tool", "developer", "specialist"}
            }
        ]
    },
    "database engineer": {
        "required": {"database"},
        "any_of": {"engineer", "administration", "analyst"},
    },
    "deep learning engineer": {"deep", "learn"},
    "computer vision specialist": {
        "required": {"vision"},
        "any_of": {"specialist", "computer", "engineer" },
    },
    "LLM / GenAI": {
        "alternatives": [
            {
                "required": {"artificial", "intelligence"},
                "any_of": {"generative", "gen"},
            },
            {
                "required": {"genai"},
                "any_of": {"developer", "engineer", "architect"},
            },
            {
                "required": {"large", "language", "model"},
                "any_of": {"developer", "engineer", "architect"},
            }
        ]
    },
    "machine learning engineer": {
        "alternatives": [
            {
                "required": {"machine", "learn"},
                "any_of": {"engineer"},
            },
            {
                "required": {"mlops"},
                "any_of": {"engineer"},
            },
            {
                "required": {"mllm"},
                "any_of": {"engineer"}
            },
        ]
    },  
    "nlp engineer": {"natural", "language", "process", "engineer"},

    "sql developer": {
        "required": {"developer"},
        "any_of": {"postgressql", "mysql", "sql", "oracle", "plsql"},
    },
    "sql engineer": {
        "required": {"engineer"},
        "any_of": {"postgressql", "mysql", "sql", "oracle", "plsql"},
    },
}


other_job_title_mapping = {
    "Other specialist: data governance": {
        # Additional Title Classification
        "required": {"data"},
        "any_of": {"governance", "steward", "management"},
    },
    "Other specialist: data product designer": {
        # Additional Title Classification
        "data", "product", "designer"
    },
    "Other specialist: devOps": {
        # Additional Title Classification
        "required": {"devops"},
        "any_of": {"developer", "engineer", "business"}
    },
    "Other specialist: cloud specialist": {
        # Additional Title Classification
        "alternatives": [
            {
                "required": {"cloud"},
                "any_of": {"architect", "consultant" "developer", "engineer", "operation", "specialist"}
            },
            {
                "required": {"aws"},
                "any_of": {"architect", "consultant" "developer", "engineer", "operation", "specialist"}
            },
            {
                "required": {"azure"},
                "any_of": {"architect", "consultant" "developer", "engineer", "operation", "specialist"}
            },
        ]
    },
    "Other specialist: automation": {
        "alternatives": [
            {
                "required": {"rpa"},
            },
            {
                "required": {"vba"},
            }
        ]
    },
    "Other specialist: cybersecurity": {
        # Additional Title Classification
        "alternatives": [
            {
                "required": {"penetration", "test"},
            },
            {
                "required": {"cyber", "security"},
                "any_of": {"architect", "consultant" "developer", "engineer", "operation", "specialist"}
            },
            {
                "required": {"security"},
                "any_of": {"architect", "consultant" "developer", "engineer", "operation", "specialist"},
            }
        ]
    },

}



job_variant_mapping = {
    "administrator": "administration",
    "analysts": "analyst", "analysis": "analyst", "analyzing": "analyst",
    "architecture": "architect", "architecting": "architect",
    "consultants": "consultant", "consulting": "consultant",
    "developers": "developer", "developing": "developer", "development": "developer",
    "engineers": "engineer", "engineering": "engineer",
    "learning": "learn", "learns": "learn", "learned": "learn",
    "managers": "manager", "managing": "manager", "mangement": "manager",
    "operations": "operation", "operating": "operation",
    "researchers": "research", "researcher": "research", "researching": "research",
    "scientist": "science", "scientists": "science", "scientifying": "science",
    "specialists": "specialist", "specializing": "specialist",
    "strategists": "strategy", "strategizing": "strategy", "strategies": "strategy",
    "testers": "test", "testing": "test",
}

# Words to ignore for core roles
noise_words = {"based", "contract", "english", "fluency", "grad",
                "intern", "internship", "junior", "lead", "level",
                "mid", "new", "remote", "required", "senior", "welcome",
                "enterprise", "urgent"
            }

# %%
def normalize_job_title(title):

    # Tokenize the title 
    doc = nlp(title.lower())

    # List to store normalized tokens
    tokens_set = set()

    for token in doc:

        if token.is_punct or token.is_space or token.is_stop:
            continue
        
        # Get both original and lemma forms
        original_word = re.sub(r"[-_.,(){}\[\]/]", " ", token.text.lower())
        lemma_word = re.sub(r"[-_.,(){}\[\]/]", " ", token.lemma_.lower())


        # Check if the word is an abbreviation or a variant
        for word in {original_word, lemma_word}:
            for w in word.split():
                # Ignore noise words
                if not w or w in noise_words:
                    continue

                # Expand abbreviations
                if w in abbr_dict:
                    tokens_set.update(abbr_dict[w])

                # Check if the word is a variant
                elif w in job_variant_mapping:
                    tokens_set.add(job_variant_mapping[w])
                else:
                    tokens_set.add(w)

    print(title, "->", tokens_set)
    return tokens_set

def match_job_title(tokens_set, mapping):
    # Alternative mapping
    if isinstance(mapping, dict) and "alternatives" in mapping:
        for option in mapping["alternatives"]:
            required = option.get("required", set())
            any_of = option.get("any_of", set())
            if required.issubset(tokens_set) and (not any_of or tokens_set & any_of):
                return True
        return False

    
    # Flexible mapping
    if isinstance(mapping, dict):
        required = mapping.get("required", set())
        any_of = mapping.get("any_of", set())

        # All required must be present, at least one of any_of (if any_of not empty)
        if required.issubset(tokens_set) and (not any_of or tokens_set & any_of):
            return True

    # Strict mapping
    elif isinstance(mapping, set):
        if mapping.issubset(tokens_set):
            return True

    return False



def normalize_title(row, title_cache):
    search_kw = row["search_keyword"].lower()
    raw_words_set = title_cache[row["title"]]

    # --- Step 1: Search keyword priority ---
    if search_kw in job_title_mapping:
        mapping = job_title_mapping[search_kw]

        if match_job_title(raw_words_set, mapping):
            return search_kw

    # --- Step 2: Fallback: check job title text ---
    for normalized, mapping in job_title_mapping.items():
        if match_job_title(raw_words_set, mapping):
            return normalized

    # --- Step 3: Nothing matched ---
    return "Unclassified"


# --- FAST NORMALIZATION: pre-process unique titles ---
unique_titles = combined_df["title"].unique()
title_cache = {title: normalize_job_title(title) for title in unique_titles}

combined_df["normalized_title"] = combined_df.apply(lambda row: normalize_title(row, title_cache), axis=1)
# add a parameter for job title mapping

# then do the combine_df again, but this time, only for those with unclassified titles, and do the otehr mapping this time
# Out:
# AI Engineer -> {'engineer', 'artificial', 'intelligence'}
# AI Engineer (Contract 1 Year) - EGG Digital -> {'engineer', 'contract', 'egg', 'artificial', 'year', 'digital', '1', 'intelligence'}
# AI Engineer (Pathum Thani) -> {'engineer', 'pathum', 'artificial', 'thani', 'intelligence'}
# Responsible AI Engineer -> {'engineer', 'artificial', 'intelligence', 'responsible'}
# Senior AI Engineer (EGG Digital) -> {'engineer', 'egg', 'artificial', 'digital', 'intelligence'}
# Machine Learning Engineer (Project Algorithmic Trading) -> {'engineer', 'machine', 'project', 'algorithmic', 'learn', 'trading'}
# AI Engineer (Innovation Department) -> {'engineer', 'department', 'artificial', 'innovation', 'intelligence'}
# AI Solutions Analyst -> {'solution', 'artificial', 'analyst', 'solutions', 'intelligence'}
# Data Engineer (AI Engineer) -> {'data', 'engineer', 'artificial', 'intelligence'}
# Data Scientist (AI Engineer) -> {'engineer', 'science', 'artificial', 'data', 'intelligence'}
# AI/ML Engineer -> {'engineer', 'machine', 'artificial', 'learn', 'intelligence'}
# Senior Data Scientist -> {'data', 'datum', 'science'}
# Chief AI Officer (CAIO) -> {'caio', 'officer', 'artificial', 'chief', 'intelligence'}
# Data Scientist (AI on Digital Marketing & Hyper-Personalization) -> {'marketing', 'science', 'personalization', 'artificial', 'digital', 'data', 'intelligence', 'hyper'}
# Network Engineer or ML/AI Systems Architect Staff วิศวกรเครือข่าย สถาปนิกระบบ -> {'network', 'engineer', 'architect', 'staff', 'สถาปนิกระบบ', 'learn', 'systems', 'system', 'machine', 'artificial', 'วิศวกรเครือข่าย', 'intelligence'}
# AI Software Engineer -> {'software', 'engineer', 'artificial', 'intelligence'}
# AI Integrator / AI Data Engineer -> {'engineer', 'artificial', 'datum', 'data', 'intelligence', 'integrator'}
# Senior Data Engineer (Generative AI Solution) -> {'engineer', 'artificial', 'intelligence', 'generative', 'data', 'solution', 'datum'}
# AI/ML Specialist, Developer -> {'developer', 'machine', 'specialist', 'artificial', 'learn', 'intelligence'}
# ExxonMobil IT Internship 2026 -> {'internship', 'exxonmobil', '2026'}
# AI Specialist/Lead (Innovation & Business Transformation) -> {'specialist', 'artificial', 'innovation', 'business', 'intelligence', 'transformation'}
# Data Engineer + Data Analyst -> {'engineer', 'analyst', '+', 'data', 'datum'}
# Department Manager, AI -  Data Engineer -> {'manager', 'engineer', 'department', 'datum', 'artificial', 'data', 'intelligence'}
# Senior AI/ML Engineer (near Mega Bangna) -> {'engineer', 'machine', 'bangna', 'artificial', 'learn', 'mega', 'intelligence', 'near'}
# Business Improvement & AI Specialist -> {'specialist', 'artificial', 'business', 'intelligence', 'improvement'}
# Internship Students - AI Developer -> {'artificial', 'developer', 'student', 'internship', 'intelligence', 'students'}
# Business Intelligence Analyst (AI Focus) -> {'focus', 'artificial', 'analyst', 'business', 'intelligence'}
# Digital & AI Manager (Boon rawd Trading Company) -> {'manager', 'rawd', 'boon', 'artificial', 'company', 'digital', 'trading', 'intelligence'}
# Data Application Engineer -> {'application', 'data', 'engineer'}
# Data Partner - Business Writer- Thai Speakers (Global, Remote-Based) -> {'remote', 'thai', 'based', 'writer', 'base', 'global', 'speaker', 'speakers', 'data', 'business', 'partner'}
# AI Product Owner Team Lead -> {'product', 'team', 'artificial', 'owner', 'intelligence'}
# AI Prompt Designer (English Expertise) -> {'expertise', 'designer', 'artificial', 'prompt', 'intelligence', 'english'}
# Machine Learning Engineer -> {'machine', 'engineer', 'learn'}
# Artificial Intelligence Analyst (AI) -> {'artificial', 'analyst', 'intelligence'}
# Senior Solution Delivery Engineer (Data & AI) -> {'engineer', 'intelligence', 'solution', 'artificial', 'delivery', 'data', 'datum'}
# Data Scientist - AI -> {'data', 'artificial', 'intelligence', 'science'}
# Digital Cloud & AI Solution Engineer – Innovative Data Platform -> {'engineer', 'cloud', 'solution', 'platform', 'datum', 'artificial', 'digital', 'data', 'innovative', 'intelligence'}
# Technical Account Manager (Remote work)(Technology), Bangkok, Thailand -> {'manager', 'account', 'remote', 'technology', 'bangkok', 'thailand', 'work', 'technical'}
# Product Owner (Gen AI Product) -> {'gen', 'artificial', 'intelligence', 'product', 'owner'}
# Automated Quality Assurance Engineer (Mid - Senior) -> {'automate', 'quality', 'assurance', 'engineer', 'mid', 'automated'}
# Cloud & AI Solution Engineer – Innovative AI Applications -> {'applications', 'engineer', 'cloud', 'solution', 'artificial', 'application', 'innovative', 'intelligence'}
# SMT IE/AE Engineer - (Chachoengsao) -> {'smt', 'engineer', 'chachoengsao', 'ie', 'ae'}
# Manager of Machine Learning/AI -> {'manager', 'artificial', 'learn', 'machine', 'intelligence'}
# Software Tester -> {'software', 'tester'}
# AI Transformation Specialist -> {'specialist', 'artificial', 'intelligence', 'transformation'}
# Data Scientist (Mid to Senior Level) -> {'data', 'mid', 'level', 'science'}
# Data Scientist -> {'data', 'science'}
# Pre-Sales Engineer -> {'pre', 'engineer', 'sales'}
# Senior AI Developer (Edecation / IT / Up to 100 K (ID: 675915)) -> {'k', 'developer', '100', 'd', 'artificial', 'edecation', 'intelligence', '675915'}
# Machine Learning Engineer (ML Engineer) Senior/Lead -> {'engineer', 'learn', 'machine'}
# [Cooperative Internship 2025] MLOps Engineer Intern -> {'cooperative', 'engineer', 'internship', 'mlop', 'mlops', '2025'}
# Senior Delivery Consultant - AI/ML , ASEAN Professional Services -> {'asean', 'consultant', 'learn', 'service', 'services', 'professional', 'machine', 'artificial', 'delivery', 'intelligence'}
# Data Scientist (On-Site) -> {'data', 'site', 'science'}
# AI Specialist ( R&D ) -> {'specialist', 'artificial', 'intelligence', 'r&d'}
# AI Senior Software Developer (Silom) -> {'developer', 'silom', 'artificial', 'software', 'intelligence'}
# AI Governance -> {'governance', 'artificial', 'intelligence'}
# IT-AI Programmer: Join Tungaloy-NTK in Chonburi -> {'join', 'chonburi', 'programmer', 'artificial', 'tungaloy', 'intelligence', 'ntk'}
# Data Scientist (Analytics AI / Application Developer) - Based in Korat -> {'developer', 'analytics', 'based', 'base', 'korat', 'application', 'science', 'analytic', 'artificial', 'data', 'intelligence'}
# MLOps Engineer – Bangkok-based (Full Relocation Package Provided) -> {'engineer', 'provide', 'bangkok', 'based', 'package', 'base', 'relocation', 'provided', 'mlops'}
# Presales Specialist -> {'presales', 'specialist'}
# Presales -> {'presale', 'presales'}
# AI & Tech Specialist -> {'specialist', 'tech', 'artificial', 'intelligence'}
# Senior Tech Architect -> {'architect', 'tech'}
# Tooling Software Sr. Engineer -> {'software', 'engineer', 'tooling', 'sr'}
# Principal Software Engineer – (MLOPs) Machine Learning Operations (Bangkok based -> {'engineer', 'machine', 'operations', 'bangkok', 'based', 'principal', 'base', 'mlop', 'learn', 'software', 'mlops', 'operation'}
# Lead DS (Data Scientist) Bangkok based, Relocation provided -> {'provided', 'provide', 'bangkok', 'science', 'based', 'ds', 'base', 'relocation', 'data', 'datum'}
# AI engineer -> {'engineer', 'artificial', 'intelligence'}
# Senior Data Scientist and AI -> {'artificial', 'science', 'intelligence', 'data', 'datum'}
# DevOps Engineer  (Mid-level/Senior) -> {'devops', 'engineer', 'mid', 'level'}
# Senior Full Stack Engineer (Gen AI Startup) -> {'engineer', 'gen', 'artificial', 'startup', 'stack', 'intelligence'}
# AI Software Engineer (Fullstack) -> {'engineer', 'fullstack', 'artificial', 'software', 'intelligence'}
# Data Scientist (Innovation Team) -> {'innovation', 'data', 'team', 'science'}
# AI Prompter -> {'artificial', 'intelligence', 'prompter'}
# AI Engineer Staff (Computer Vision + Embedded Deployment + Web Integration) -> {'engineer', 'computer', 'staff', 'embedded', 'embed', 'deployment', 'artificial', 'vision', '+', 'integration', 'web', 'intelligence'}
# Senior Data Scientist & AI Specialist -> {'science', 'specialist', 'artificial', 'data', 'intelligence'}
# Senior Software Engineer, AI Model serving - Asia -> {'serve', 'engineer', 'artificial', 'serving', 'asia', 'software', 'intelligence', 'model'}
# Image Processing / ML Engineer -> {'image', 'processing', 'engineer', 'machine', 'learn'}
# Senior AI/ML Engineer -> {'engineer', 'machine', 'artificial', 'learn', 'intelligence'}
# AI Engineer (SAP Business AI) -> {'engineer', 'sap', 'artificial', 'business', 'intelligence'}
# AI Agent Developer -> {'developer', 'artificial', 'intelligence', 'agent'}
# Senior Machine Learning Engineer -> {'machine', 'engineer', 'learn'}
# AI/ML Process Engineer II (Korat Plant) -> {'engineer', 'ii', 'machine', 'korat', 'process', 'artificial', 'learn', 'plant', 'intelligence'}
# AI Specialist -> {'specialist', 'artificial', 'intelligence'}
# วิศวกรพัฒนาโซลูชัน Solution Engineer (IOT) -> {'engineer', 'solution', 'วิศวกรพัฒนาโซลูชัน', 'iot'}
# AI Coach -> {'artificial', 'intelligence', 'coach'}
# Data & AI Team -> {'data', 'team', 'artificial', 'intelligence'}
# Python Developer -> {'developer', 'python'}
# IoT Engineer -> {'engineer', 'iot'}
# AI Solution Channel Executive(On-site) -> {'executive', 'solution', 'site', 'channel', 'artificial', 'on', 'intelligence'}
# AI ML Intern -> {'machine', 'artificial', 'intelligence', 'learn'}
# Remote AI Model-training Engineer (Part-time or Full time Contract) -> {'remote', 'engineer', 'contract', 'time', 'artificial', 'training', 'intelligence', 'model'}
# AI Narrative Designer (Advanced English) -> {'narrative', 'designer', 'artificial', 'advanced', 'intelligence', 'english'}
# JUNIOR SOFTWARE R&D ENGINEER -> {'software', 'r&d', 'engineer'}
# Sales & Business Development Executive (Data & AI) - New Graduated are welcome -> {'sales', 'developer', 'executive', 'graduate', 'sale', 'new', 'welcome', 'graduated', 'artificial', 'data', 'business', 'intelligence'}
# Data Scientist (ML/AI Focus) -> {'focus', 'artificial', 'learn', 'science', 'machine', 'data', 'intelligence'}
# Software Engineer, Platform - Asia -> {'software', 'engineer', 'platform', 'asia'}
# Intern - AI Software Developer (Studying Bachelor's or Master's degree) -> {'developer', 'master', 'degree', 'studying', 'study', 'artificial', 'bachelor', 'software', 'intelligence'}
# ผู้สอนการเขียน Prompt สำหรับ AI (พาร์ทไทม์) -> {'ผู้สอนการเขียน', 'สำหรับ', 'พาร์ทไทม์', 'artificial', 'prompt', 'intelligence'}
# Python Developer (Odoo) -> {'odoo', 'developer', 'python'}
# AWS Solutions Architect -> {'architect', 'aws', 'aw', 'solution', 'solutions'}
# ioT Developer -> {'developer', 'iot'}
# (NEW GRAD ONLY) Data Science -> {'data', 'new', 'science', 'grad'}
# MS Engineer (L1) -> {'engineer', 'l1', 'ms'}
# Support Service Delivery Administrator -> {'service', 'delivery', 'administration', 'support'}
# MS Engineer (L2) -> {'engineer', 'ms', 'l2'}
# Collaboration Managed Services Engineer (L1) -> {'service', 'services', 'engineer', 'manage', 'collaboration', 'l1', 'managed'}
# Senior Software Engineer (Strategy & Technology) -> {'software', 'engineer', 'strategy', 'technology'}
# Cloud Managed Services Engineer (L2) -> {'service', 'services', 'engineer', 'manage', 'cloud', 'managed', 'l2'}
# MS Engineer (L1)-2 -> {'engineer', 'l1', 'ms', '2'}
# Project Manager -> {'manager', 'project'}
# ผู้จัดการด้านผลิตภัณฑ์  ( Product manager) -> {'manager', 'product', 'ผู้จัดการด้านผลิตภัณฑ์'}
# Digital Product Owner -> {'product', 'owner', 'digital'}
# Application Team Lead -> {'application', 'team'}
# Investment Product Analyst Manager -> {'investment', 'analyst', 'manager', 'product'}
# Product Development Manager -> {'manager', 'product', 'developer'}
# Product Development (Senior Level/ and Manager Level) -> {'manager', 'product', 'developer', 'level'}
# Project Manager / Product Owner (Software) -> {'manager', 'product', 'project', 'software', 'owner'}
# Product Manager (Software / Cloud) 60-80K -> {'manager', '60', 'cloud', 'product', '80k', 'software'}
# Mobile Software Product Manager(Mandarin Speaking) -> {'manager', 'speaking', 'mandarin', 'mobile', 'product', 'software', 'speak'}
# Senior Leader, Cloud Solutions (Product Manager) -> {'manager', 'cloud', 'product', 'leader', 'solution', 'solutions'}
# Product Manager -> {'manager', 'product'}
# No-code MES Solution Engineer, Life Sciences -> {'mes', 'sciences', 'engineer', 'science', 'solution', 'code', 'me', 'life'}
# Technical Product Manager – Data/ Machine Learning (Bangkok-based, relocation -> {'manager', 'machine', 'bangkok', 'based', 'product', 'base', 'technical', 'relocation', 'learn', 'data'}
# Division Manager – Application Development -> {'manager', 'division', 'developer', 'application'}
# Specialist, Technology Strategy & Governance (Advance Engineer) -> {'advance', 'engineer', 'technology', 'specialist', 'governance', 'strategy'}
# Product Management Team -> {'team', 'product', 'management'}
# IT Business Partner Manager (AI/IOT Implementer) -> {'manager', 'artificial', 'implementer', 'business', 'intelligence', 'partner', 'iot'}
# Senior Technical Product Manager (Bangkok, Hybrid) (Visa and Relocation... -> {'manager', 'visa', 'bangkok', 'product', 'technical', 'relocation', 'hybrid'}
# Business Analyst (AI & Software  Products) -> {'product', 'products', 'artificial', 'software', 'analyst', 'business', 'intelligence'}
# Product Manager - Thailand -> {'manager', 'thailand', 'product'}
# Ecommerce Manager -> {'manager', 'ecommerce'}
# ผู้จัดการแผนกผลิตภัณฑ์ (Product Manager) -> {'manager', 'ผู้จัดการแผนกผลิตภัณฑ์', 'product'}
# Tech Internship -> {'internship', 'tech'}
# Head of Tech & Product Development -> {'tech', 'product', 'developer', 'head'}
# Business Analyst / Product Owner -> {'product', 'analyst', 'business', 'owner'}
# Product Manager for Marketplace -> {'manager', 'product', 'marketplace'}
# Lead Technical Product Manager (Bangkok, Hybrid) (Visa and Relocation Package... -> {'manager', 'visa', 'bangkok', 'package', 'product', 'technical', 'relocation', 'hybrid'}
# Senior Backend Developer (Kotlin/Java) (Visa and work permit sponsorship to... -> {'kotlin', 'developer', 'visa', 'sponsorship', 'work', 'permit', 'java', 'backend'}
# AI Operator — Phrom Phong, On‑site -> {'operator', 'phong', 'artificial', 'on‑site', 'phrom', 'intelligence'}
# Business Development Manager – Financial AI Solutions Sales -> {'manager', 'sales', 'developer', 'sale', 'financial', 'solutions', 'business', 'solution', 'artificial', 'intelligence'}
# Marketing Support -> {'marketing', 'support'}
# Full Stack PHP/Web Programmer -> {'programmer', 'stack', 'web', 'php'}
# Senior Graphic Designer -> {'designer', 'graphic'}
# Software & Platform Engineering Team -> {'team', 'software', 'engineer', 'platform'}
# Marketing Associate -> {'marketing', 'associate'}
# Software Architect Team Lead  (AI, Cloud, & DevOps) >>> Urgently -> {'architect', 'devop', 'software', 'cloud', 'urgently', 'devops', 'team', 'artificial', '>', 'intelligence'}
# Marketing Communication & BD & Sustainability Manager -> {'marketing', 'manager', 'market', 'sustainability', 'bd', 'communication'}
# Consumer Business Insight Executive -> {'consumer', 'business', 'executive', 'insight'}
# Assistant IT Manager (AIOps & Projects) -> {'manager', 'aiops', 'projects', 'assistant', 'project', 'aiop'}
# Senior Specialist - Data analyst -> {'data', 'analyst', 'specialist'}
# Senior UX/UI Designer -> {'designer', 'ui', 'ux'}
# Senior Leader, Online Experience & Digital Insight -> {'experience', 'leader', 'insight', 'digital', 'online'}
# Sustainability Data Specialist -> {'data', 'sustainability', 'specialist'}
# Business Development Executive (Sales Executive) ประจำภาคอีสาน/ภาคใต้ -> {'ภาคใต้', 'sales', 'developer', 'executive', 'sale', 'ประจำภาคอีสาน', 'business'}
# Software Tester for Web/App Projects (Contract 1 Year) -> {'tester', 'contract', 'projects', 'app', 'project', 'year', 'software', 'web', '1'}
# Management Trainee -> {'trainee', 'management'}
# Senior Business Development Officer (Sales) - Carbon Credit / ESG [Contract] -> {'carbon', 'credit', 'sales', 'developer', 'contract', 'esg', 'sale', 'officer', 'business'}
# Technical Sales Support (International) (สำนักงานใหญ่) -> {'sales', 'สำนักงานใหญ่', 'international', 'sale', 'technical', 'support'}
# Marketing Executive -> {'marketing', 'executive'}
# Senior HR Technology Analyst - HRIS (Hybrid) -> {'technology', 'hris', 'analyst', 'hr', 'hybrid'}
# Business Development Associate (6 Month Contract) -> {'developer', 'contract', 'month', '6', 'business', 'associate'}
# Strategic and Risk Management (Assistant Manager Level) -> {'manager', 'assistant', 'management', 'risk', 'strategic', 'level'}
# Specialist, Data Science -> {'data', 'specialist', 'science', 'datum'}
# Design Engineer -> {'engineer', 'design'}
# Digital Marketing Executive -> {'marketing', 'executive', 'digital'}
# Game Design & Development (Incubation Project) (Contract) -> {'developer', 'contract', 'game', 'project', 'design', 'incubation'}
# Software Developer Specialist ( R&D ) -> {'software', 'specialist', 'developer', 'r&d'}
# Fullstack Engineer -> {'fullstack', 'engineer'}
# Strategic Planner (Senior/ Manager) -> {'manager', 'planner', 'strategic'}
# Media Search Analyst - Thai Speakers -> {'thai', 'medium', 'speaker', 'media', 'speakers', 'analyst', 'search'}
# Location Assistant -> {'assistant', 'location'}
# MIS Specialist (Procurement) -> {'mis', 'procurement', 'specialist'}
# Business Analyst (IT & Digital Solution) -> {'analyst', 'solution', 'business', 'digital'}
# Solution Architect – Automatic Packing Machine -> {'packing', 'architect', 'machine', 'automatic', 'solution'}
# Associate Director (ID:681794) -> {'director', 'id:681794', 'associate'}
# Senior Lawyer - Corporate & Commercial -> {'corporate', 'lawyer', 'commercial'}
# Sales Engineer (Robotic Solutions) -> {'engineer', 'sales', 'solution', 'sale', 'robotic', 'solutions'}
# IT Instructor (ARIT) -> {'instructor', 'arit'}
# Data Science and Analytics -> {'data', 'analytics', 'science', 'analytic'}
# Marketing Assistant – Savoury (SEA) -> {'marketing', 'savoury', 'assistant', 'sea'}
# Coding Teacher and Curriculum Officer (Code Genius) / Welcome New Grads -> {'grads', 'new', 'genius', 'teacher', 'officer', 'code', 'grad', 'curriculum', 'welcome', 'coding'}
# Senior Interior Designer (Healthcare / Workplace / Hospitality) -> {'hospitality', 'designer', 'interior', 'healthcare', 'workplace'}
# Officer, Consumer Quality Management -> {'consumer', 'management', 'quality', 'officer'}
# Lead/ Staff Data Scientist (Bangkok based, relocation provided) -> {'provided', 'provide', 'bangkok', 'based', 'science', 'base', 'staff', 'relocation', 'data'}
# Data Science Manager (Bangkok based, relocation provided) -> {'manager', 'provided', 'provide', 'bangkok', 'based', 'science', 'base', 'relocation', 'data'}
# Business Integration & Operation Associate (Boonrawd Trading Company) -> {'boonrawd', 'company', 'integration', 'trading', 'business', 'operation', 'associate'}
# Project Management Manager – Strategic Project (Bangkok-based role) -> {'manager', 'bangkok', 'based', 'project', 'management', 'base', 'strategic', 'role'}
# AI Developer -> {'developer', 'artificial', 'intelligence'}
# Scientist II -> {'science', 'ii'}
# Marketing Team Lead -> {'marketing', 'team'}
# Associate UX/UI Designer | Bangkok Office -> {'|', 'bangkok', 'designer', 'ui', 'ux', 'office', 'associate'}
# Data Scientist (Data Solutions, Retail Banking) -> {'banking', 'science', 'solution', 'retail', 'data', 'solutions', 'datum'}
# Media Search Analyst (Thai speakers) -> {'thai', 'medium', 'speaker', 'media', 'speakers', 'analyst', 'search'}
# Lead Generation & Content Specialist -> {'generation', 'specialist', 'content'}
# อาจารย์ประจำ สังกัด ศูนย์ความเป็นเลิศด้านปัญญาประดิษฐ์และการคำนวณขั้นสูง... -> {'ศูนย์ความเป็นเลิศด้านปัญญาประดิษฐ์และการคำนวณขั้นสูง', 'สังกัด', 'อาจารย์ประจำ'}
# Executive Assistant (Thai & Chinese & English Speaking) (New grads welcome) -> {'speaking', 'executive', 'grads', 'thai', 'assistant', 'chinese', 'welcome', 'grad', 'new', 'english'}
# Marketing design / Product development internship -> {'marketing', 'developer', 'internship', 'product', 'design'}
# Executive Assistant to Chairman and CEO -> {'executive', 'assistant', 'ceo', 'chairman'}
# Associate Design Director - Hospitality and Residential -> {'residential', 'hospitality', 'design', 'associate', 'director'}
# Business Development Executive -> {'executive', 'business', 'developer'}
# Data Scientist Intern -> {'data', 'science'}
# Junior Marketing Executive -> {'marketing', 'executive'}
# Project and Product Team Leader -> {'product', 'team', 'project', 'leader'}
# SALES INTERNSHIP -> {'internship', 'sales', 'sale'}
# Tech Lead, Web Core Product & Chrome Extension - Asia -> {'core', 'product', 'extension', 'chrome', 'asia', 'tech', 'web'}
# Tech Lead (Digital Asset) -> {'asset', 'tech', 'digital'}
# Business Analyst -> {'analyst', 'business'}
# Business Strategy Manager -> {'manager', 'business', 'strategy'}
# Senior Tax Accountant -> {'accountant', 'tax'}
# Creative Copywriter -> {'copywriter', 'creative'}
# Digital News Creator  (English Fluency Required) -> {'creator', 'fluency', 'required', 'digital', 'news', 'require', 'english'}
# Business Manager -> {'manager', 'business'}
# Marketing Director -> {'marketing', 'director'}
# Digital Marketing Manager -> {'marketing', 'manager', 'digital'}
# Senior Statistical Assistant (Education) -> {'assistant', 'education', 'statistical'}
# Technology Solutions Business Lead -> {'business', 'solution', 'solutions', 'technology'}
# Senior Marketing and Content Creator -> {'marketing', 'creator', 'content'}
# ECONOMIC AFFAIRS OFFICER, P4 -> {'affairs', 'officer', 'p4', 'economic', 'affair'}
# Graphic Designer & Content Creator (ธุรกิจกอล์ฟ) -> {'creator', 'graphic', 'ธุรกิจกอล์ฟ', 'content', 'designer'}
# IT&D Senior Business Analyst - R&D -> {'it&d', 'analyst', 'business', 'r&d'}
# Sales Manager, Thailand -> {'manager', 'sales', 'sale', 'thailand'}
# Integrated Marketing General Manager -> {'marketing', 'manager', 'integrate', 'general', 'integrated'}
# Language and Desktop Publishing Assistant, G6 -> {'language', 'assistant', 'publishing', 'desktop', 'g6'}
# Chief Marketing Officer (CMO) -> {'marketing', 'chief', 'cmo', 'officer'}
# Equity Research - Analyst/Associate -> {'research', 'analyst', 'equity', 'associate'}
# Marketing Manager -> {'marketing', 'manager'}
# Local Content Creator (Video & How-To Guides) -> {'creator', 'video', 'guides', 'guide', 'content', 'local'}
# Entrepreneur In Residence (Bangkok, Visa and Relocation Package Provided) -> {'visa', 'provide', 'bangkok', 'residence', 'entrepreneur', 'package', 'relocation', 'provided'}
# Technology Consulting - Enterprise Data -> {'technology', 'consultant', 'data', 'datum', 'enterprise'}
# Marketing Lead (B2B) -> {'marketing', 'b2b'}
# Strategic Planning Executive -> {'executive', 'planning', 'strategic'}
# Sales Development Representative -> {'representative', 'sales', 'developer', 'sale'}
# [INTERNSHIP] Creator Engagement Intern -> {'internship', 'engagement', 'creator'}
# Marketing and Communication Lead (Manager / Senior Manager) -> {'marketing', 'manager', 'communication'}
# HR Assistant Manager -> {'manager', 'assistant', 'hr'}
# Customer Intelligence Analyst (Urgent!) -> {'customer', 'analyst', 'urgent', 'intelligence'}
# Creative Manager -> {'manager', 'creative'}
# Creative Director -> {'creative', 'director'}
# Chief Financial Officer (CFO) -> {'financial', 'chief', 'cfo', 'officer'}
# Department Manager - Marketing Creative -> {'manager', 'marketing', 'creative', 'department'}
# Sales & Marketing Specialist (Bitkub Academy - Learning Platform) -> {'marketing', 'sales', 'bitkub', 'sale', 'specialist', 'platform', 'learn', 'academy'}
# Process Improvement (Digital Transformation) Specialist -> {'specialist', 'process', 'digital', 'transformation', 'improvement'}
# Corp Investigation Legal Counsel Manager -> {'legal', 'manager', 'counsel', 'investigation', 'corp'}
# Plant Engineer; Technology & Asset Management -> {'engineer', 'technology', 'management', 'plant', 'asset'}
# Biddable Media Buyer -> {'media', 'biddable', 'buyer', 'medium'}
# Talent Acquisition Supervisor - Manager (72456) -> {'manager', 'talent', 'acquisition', 'supervisor', '72456'}
# Global Business Strategy Manager -> {'manager', 'business', 'strategy', 'global'}
# Senior IT Business Partner Manager -> {'manager', 'business', 'partner'}
# Digital Transformation & OPEX Expert -> {'transformation', 'opex', 'expert', 'digital'}
# Data Network Engineer -> {'engineer', 'data', 'network'}
# Assistant Country Marketing Manager -> {'marketing', 'country', 'assistant', 'manager'}
# IT Technology Architect -> {'architect', 'technology'}
# Digital Marketing Manager (Based in Bangkok) -> {'marketing', 'manager', 'bangkok', 'based', 'base', 'digital'}
# Digital Innovation Section Manager -> {'innovation', 'manager', 'digital', 'section'}
# Group Chief Operating Officer (COO) -> {'coo', 'operating', 'officer', 'chief', 'group'}
# Graphic Designer (平面设计师)- Chinese Speaking -> {'speaking', 'graphic', '平面设计师', 'chinese', 'designer', 'speak'}
# Assistant Human Resources Director -> {'assistant', 'resources', 'resource', 'human', 'director'}
# Art Director for Accenture Song (Junior-Mid Level) -> {'accenture', 'song', 'mid', 'level', 'art', 'director'}
# Director of Innovation Development -> {'innovation', 'developer', 'director'}
# Head of Recruitment -> {'recruitment', 'head'}
# Business Development (Google Workspace) -> {'workspace', 'business', 'developer', 'google'}
# Head of E-Commerce -> {'e', 'commerce', 'head'}
# Head of Retail Customer Segment & Marketing (Group Head) -> {'marketing', 'customer', 'segment', 'retail', 'group', 'head'}
# Senior Manager, Fulfillment Operations -> {'manager', 'operations', 'fulfillment', 'operation'}
# Software QA Lead – Technology Solutions Company with Strong Growth -> {'quality', 'assurance', 'technology', 'solution', 'strong', 'company', 'growth', 'software', 'solutions'}
# Portfolio Manager (Customer Value Management - CVM) -> {'manager', 'value', 'management', 'cvm', 'portfolio', 'customer'}
# DIGITAL MARKETING MANAGER -> {'marketing', 'manager', 'digital'}
# Senior Manager - Corporate Strategy -> {'manager', 'corporate', 'strategy'}
# Programmer (สนใจด้านระบบเทรด / Automation) -> {'programmer', 'สนใจด้านระบบเทรด', 'automation'}
# Knowledge Management Lead -> {'management', 'knowledge'}
# Performance Creative Specialist - SEA -> {'performance', 'specialist', 'creative', 'sea'}
# Senior Media Planner & Buyer (Ads Optimizer) -> {'ads', 'ad', 'medium', 'media', 'optimizer', 'planner', 'buyer'}
# Marketing Strategy & Growth Analyst (ประจำสำนักงานเมืองทองธานี) -> {'marketing', 'ประจำสำนักงานเมืองทองธานี', 'growth', 'analyst', 'strategy'}
# Data Quality Specialist -> {'quality', 'data', 'specialist'}
# Strategic Manager -> {'manager', 'strategic'}
# Marketing Manager - Upper South (ดูแลพื้นที่ 7 จังหวัดภาคใต้ตอนบน) -> {'marketing', 'manager', 'upper', 'ดูแลพื้นที่', '7', 'จังหวัดภาคใต้ตอนบน', 'south'}
# Copywriter for Accenture Song (Junior-Mid Level) -> {'accenture', 'copywriter', 'song', 'mid', 'level'}
# Senior Legal - Outsource -> {'legal', 'outsource'}
# Sustainability Digital Marketing Specialist -> {'marketing', 'sustainability', 'specialist', 'digital'}
# Senior Project Manager, Tech Partnerships (Bangkok Based) -> {'manager', 'partnership', 'bangkok', 'based', 'project', 'base', 'partnerships', 'tech'}
# Talent Acquisition & Employer Branding -> {'talent', 'branding', 'brand', 'acquisition', 'employer'}
# Chief Risk Officer (Digital Banking), Bangkok, Thailand -> {'banking', 'bangkok', 'thailand', 'risk', 'officer', 'digital', 'chief'}
# Solution Architect -> {'architect', 'solution'}
# Data and AI Manager -> {'manager', 'intelligence', 'artificial', 'data', 'datum'}
# Performance Creative Specialist (AI & Automation) - regional SEA -> {'regional', 'artificial', 'creative', 'sea', 'intelligence', 'performance', 'automation', 'specialist'}
# Business Unit – Automatic Packing Machine -> {'packing', 'machine', 'automatic', 'business', 'unit'}
# Account Strategist, SBS Engage, Google Customer Solutions (Thai, English) -> {'account', 'thai', 'strategist', 'solution', 'english', 'sbs', 'engage', 'customer', 'solutions', 'google'}
# HR Project Manager (Bangkok based/Relocation provided) -> {'manager', 'provide', 'bangkok', 'based', 'project', 'relocation', 'hr', 'provided'}
# Creative Designer Senior Officer -> {'designer', 'creative', 'officer'}
# Digital Marketing Head, CA Asia -> {'marketing', 'asia', 'digital', 'head'}
# Senior Project Manager/Project Manager, Talent Acquisition – Based in Bangkok -> {'manager', 'talent', 'bangkok', 'acquisition', 'based', 'project', 'base'}
# Sales Representative -> {'representative', 'sales', 'sale'}
# Quality Assurance Engineer (6-months contract) -> {'quality', 'assurance', 'engineer', 'contract', 'months', 'month', '6'}
# Solution Consultant (Business Software) -> {'software', 'solution', 'business', 'consultant'}
# SAP Presales Urgently!!! -> {'presale', 'presales', 'urgently', 'sap'}
# Tencent Cloud - Quality Assurance Engineer (Thailand) -> {'quality', 'assurance', 'engineer', 'tencent', 'cloud', 'thailand'}
# Tencent Cloud – Big Data Migration Engineer (Thailand) -> {'engineer', 'tencent', 'cloud', 'thailand', 'big', 'migration', 'data'}
# Tencent Cloud - Pre-sales Senior Solution Architect (Thailand) -> {'sales', 'tencent', 'pre', 'architect', 'cloud', 'solution', 'thailand'}
# Tencent Cloud – Cloud Migration Engineer (Thailand) -> {'engineer', 'tencent', 'cloud', 'thailand', 'migration'}
# Tencent Cloud Senior Strategic Sales Executive - Thailand -> {'sales', 'tencent', 'executive', 'cloud', 'sale', 'thailand', 'strategic'}
# Services Account Executive- FSI -> {'service', 'services', 'account', 'executive', 'fsi'}
# Digital Enterprise Architect Consultant -> {'architect', 'enterprise', 'consultant', 'digital'}
# Senior Digital Enterprise Architect -> {'architect', 'enterprise', 'digital'}
# Solution Play GTM Manager for AI Apps and Agents in ASEAN -> {'manager', 'asean', 'app', 'play', 'apps', 'agent', 'solution', 'artificial', 'agents', 'intelligence', 'gtm'}
# Legal Counsel (Litigator) -> {'legal', 'counsel', 'litigator'}
# Marketing Manager (Motorsports Passion) -> {'marketing', 'manager', 'motorsport', 'motorsports', 'passion'}
# Tencent Cloud Senior Solution Architect - Thailand -> {'tencent', 'architect', 'cloud', 'solution', 'thailand'}
# Digital Data Analytics Director -> {'analytics', 'analytic', 'digital', 'data', 'director'}
# Tencent Cloud - Senior Channel/Strategic Sales Executive (Emerging Markets) -> {'sales', 'tencent', 'emerge', 'executive', 'cloud', 'sale', 'strategic', 'channel', 'markets', 'market', 'emerging'}
# Tencent Cloud - Associate Account Representative (Sales Trainee Program) -... -> {'account', 'sales', 'tencent', 'program', 'representative', 'cloud', 'sale', 'trainee', 'associate'}
# Regional Digital Marketing Specialist -> {'marketing', 'specialist', 'regional', 'digital'}
# Tencent Cloud - Cloud Project Manager (Thailand) -> {'manager', 'tencent', 'cloud', 'project', 'thailand'}
# Senior Engineer – Korat Plant (Ph.D. new graduates are welcome) -> {'engineer', 'graduate', 'korat', 'd', 'welcome', 'plant', 'new', 'graduates', 'ph'}
# CEO's Assistant -> {'assistant', 'ceo'}
# Solution Architect (Tech) -> {'architect', 'solution', 'tech'}
# Head of Data - Virtual Bank -> {'bank', 'data', 'virtual', 'head'}
# Metaverse Strategy Senior Manager -> {'manager', 'metaverse', 'strategy'}
# Senior Marketing specialist (MarTech/Tech Expert) -> {'marketing', 'expert', 'specialist', 'martech', 'tech'}
# Sr. Full Stack Developer / Squad Lead (Contract) -> {'contract', 'developer', 'sr', 'squad', 'stack'}
# Head of Platform Engineer -> {'engineer', 'platform', 'head'}
# CX Consultant – Marketing Automation -> {'marketing', 'automation', 'consultant', 'cx'}
# IT Manager -Technology Platform and Applications -> {'manager', 'applications', 'technology', 'platform', 'application'}
# Procurement & Logistics Specialist -> {'logistics', 'procurement', 'specialist'}
# อาจารย์/ผู้ช่วยศาสตราจารย์/รองศาสตราจารย์ -> {'อาจารย์', 'ผู้ช่วยศาสตราจารย์', 'รองศาสตราจารย์'}
# Associate Designer-User Experience Design -> {'experience', 'user', 'design', 'designer', 'associate'}
# Chief Technology Officer - Consumer Business -> {'consumer', 'technology', 'officer', 'chief', 'business'}
# Senior Auditor -> {'auditor'}
# Senior Software Engineer, Tech Lead -> {'software', 'engineer', 'tech'}
# Creative Marketing/Campaign -> {'marketing', 'creative', 'campaign'}
# Sales Manager -> {'manager', 'sales', 'sale'}
# Commerce Manager -> {'manager', 'commerce'}
# User Interface Designer -> {'designer', 'interface', 'user'}
# Data Engineer -> {'data', 'engineer'}
# Automation QA Engineer -> {'quality', 'automation', 'assurance', 'engineer'}
# HR Manager -> {'manager', 'hr'}
# Director, Data Center Quality Commissioning -> {'quality', 'commission', 'center', 'data', 'datum', 'commissioning', 'director'}
# Graphic Designer /Marketing Communication -> {'marketing', 'markete', 'graphic', 'designer', 'communication'}
# Strategic Planning Analyst -> {'planning', 'analyst', 'strategic'}
# Digital Ad Content Creator (English Fluency Required) -> {'creator', 'fluency', 'ad', 'content', 'required', 'digital', 'require', 'english'}
# Lead Marketing Data Analyst -> {'marketing', 'data', 'analyst', 'datum'}
# Solution Architect (GenAI), BytePlus - Thailand -> {'architect', 'solution', 'thailand', 'genai', 'byteplus'}
# Cloud Data Engineer -> {'engineer', 'data', 'cloud'}
# [TH] Innovation Tech Solution Sales - BytePlus -> {'sales', 'solution', 'sale', 'byteplus', 'tech', 'innovation', 'th'}
# Sales & Account Manager (Influencer Marketing) -> {'manager', 'marketing', 'account', 'sales', 'sale', 'influencer'}
# Head of Licensing & Compliance -> {'compliance', 'licensing', 'head'}
# Senior Data Visualization & BI Specialist -> {'visualization', 'specialist', 'data', 'bi', 'datum'}
# Senior Manager, Corporate Strategic Planning -> {'manager', 'planning', 'corporate', 'strategic'}
# Account Manager (Mobile Marketing Business) -> {'manager', 'marketing', 'account', 'mobile', 'business'}
# Senior Graphic & Motion Designer -> {'designer', 'motion', 'graphic'}
# Digital Marketing Intern -> {'marketing', 'digital'}
# Sales Manager - Samui -> {'manager', 'sales', 'samui', 'sale'}
# People & Organization Success General Manager -> {'people', 'manager', 'organization', 'general', 'success'}
# Total Rewards & HR Services Manager -> {'service', 'services', 'manager', 'reward', 'hr', 'total', 'rewards'}
# Sales Manager - Huahin -> {'manager', 'huahin', 'sales', 'sale'}
# Regional Director of Quality and Compliance -> {'quality', 'compliance', 'regional', 'director'}
# Sales Manager - Krabi -> {'manager', 'sales', 'krabi', 'sale'}
# Data Centre Technology Sales Specialist -> {'sales', 'technology', 'sale', 'specialist', 'data', 'centre', 'datum'}
# Lead Data Engineer -> {'data', 'engineer'}
# Creative Strategist -> {'strategist', 'creative'}
# OWA Asia-Pacific Corporate Strategy Lead -> {'pacific', 'owa', 'asia', 'corporate', 'strategy'}
# Senior Data Engineer -> {'data', 'engineer', 'datum'}
# Sales Manager - Pattaya -> {'manager', 'pattaya', 'sales', 'sale'}
# Sales Manager - Phuket -> {'manager', 'phuket', 'sales', 'sale'}
# Team Lead, IT Information Systems -> {'team', 'system', 'information', 'systems'}
# SQL developer -> {'sql', 'developer'}
# Key Account Manager, Modern Retail -> {'manager', 'account', 'modern', 'retail', 'key'}
# Senior Team Lead, IT Information Systems -> {'team', 'system', 'information', 'systems'}
# Principal Software Engineer (Bangkok, Hybrid) (Visa and Relocation Package... -> {'engineer', 'visa', 'bangkok', 'package', 'principal', 'relocation', 'software', 'hybrid'}
# Forensics_Investigations & Compliance_Manager to Senior Manager -> {'manager', 'investigations', 'forensics', 'compliance', 'manag', 'investigation'}
# Lead Acquisition Account Manager -> {'manager', 'acquisition', 'account'}
# Talent Acquisition Manager APAC -> {'manager', 'acquisition', 'talent', 'apac'}
# Client Success Specialist -> {'client', 'success', 'specialist'}
# Sr. Manager, Big Data -> {'manager', 'sr', 'big', 'data', 'datum'}
# Manager, iTero Marketing, South East Asia -> {'manager', 'marketing', 'east', 'asia', 'south', 'itero'}
# Technology Consulting - Data Architect -> {'technology', 'architect', 'consultant', 'data', 'datum'}
# Internship (Intern/Trainee) -> {'internship', 'trainee'}
# Digital Platform - Project Manager -> {'manager', 'project', 'platform', 'digital'}
# SAP Consultant - Fresh grads are welcome to apply -> {'fresh', 'grads', 'consultant', 'sap', 'grad', 'apply', 'welcome'}
# Associate Consultant/ Consultant -> {'consultant', 'associate'}
# Business Analyst/Consultant (Business Software) -> {'software', 'analyst', 'business', 'consultant'}
# SAP Consultant (FI / CO Modules) -> {'modules', 'module', 'co', 'consultant', 'sap', 'fi'}
# Logistics and Supply Chain Manager -> {'supply', 'manager', 'logistics', 'logistic', 'chain'}
# CEO (Consumer / SNACK) / 600K - 700K -> {'consumer', 'snack', '600k', 'ceo', '700k'}
# Accounting Senior Manager -> {'manager', 'account', 'accounting'}
# Marketing Executive (Senior) / เจ้าหน้าที่การตลาด -> {'marketing', 'executive', 'เจ้าหน้าที่การตลาด'}
# Data Analytics, Reporting, and Dashboard Specialist -> {'analytics', 'specialist', 'analytic', 'data', 'reporting', 'dashboard'}
# A&A : Consultant–Senior Consultant (IT Audit and Assurance/Data Analytics) -> {'assurance', 'audit', 'analytics', 'consultant', 'a&a', 'analytic', 'data', 'datum'}
# Management Consultant for Production (Engineer, Process improvement background) -> {'engineer', 'background', 'consultant', 'management', 'process', 'production', 'improvement'}
# Marketing Data Analytics & Insight Specialist -> {'marketing', 'analytics', 'specialist', 'insight', 'analytic', 'data', 'datum'}
# Mental Health Consultant -> {'health', 'mental', 'consultant'}
# Senior Aviation Consultant/ Consultant -> {'aviation', 'consultant'}
# HR Operations & ER Manager -> {'manager', 'operations', 'er', 'hr', 'operation'}
# Financial Consultant  (IB - Merger & Acquistion)... -> {'consultant', 'merger', 'financial', 'ib', 'acquistion'}
# Technical Solution Consultant  - ConnectX  (รับหลาย level) -> {'รับหลาย', 'solution', 'consultant', 'technical', 'level', 'connectx'}
# Operations Manager (Food Manufacturing) -> {'manager', 'food', 'manufacturing', 'operations', 'operation'}
# IT Compliance / IT Auditor Consultant -> {'compliance', 'auditor', 'consultant'}
# Compensation and Benefits Management Officer -> {'management', 'officer', 'benefit', 'compensation', 'benefits'}
# Subcontracts and Cost Control Engineer -> {'engineer', 'subcontract', 'cost', 'control', 'subcontracts'}
# Senior Consultant -> {'consultant'}
# Business Intelligence Specialist -> {'specialist', 'business', 'intelligence'}
# SAP Consultant / SAP Support (CO / SD / MM) -> {'co', 'consultant', 'sap', 'sd', 'mm', 'support'}
# Investment Research -> {'investment', 'research'}
# SAP Technical Consultant -> {'technical', 'consultant', 'sap'}
# Property Consultant/ที่ปรึกษาอสังหาริมทรัพย์ -> {'property', 'consultant', 'ที่ปรึกษาอสังหาริมทรัพย์'}
# Business Analyst - Banking (Hybrid) -> {'hybrid', 'analyst', 'business', 'banking'}
# Construction Schedule Manager -> {'manager', 'construction', 'schedule'}
# Warehouse Operation Excellence - Chonburi (New Plant) -> {'warehouse', 'chonburi', 'excellence', 'plant', 'new', 'operation'}
# SAP TRM (Treasury & Risk Management) Consultant - Fresh Graduate -> {'fresh', 'graduate', 'management', 'risk', 'trm', 'sap', 'consultant', 'treasury'}
# Technical Consultant Manager (North)   (Project Sales - ภาคเหนือ) -> {'manager', 'sales', 'ภาคเหนือ', 'sale', 'project', 'consultant', 'technical', 'north'}
# Senior Consultant – Operational Excellence & Lean Transformation -> {'lean', 'consultant', 'excellence', 'operational', 'transformation'}
# SR&T : Consultant - Valuation & Modeling -> {'modeling', 'valuation', 'consultant', 'sr&t'}
# Department Manager - O2O Strategy Analyst -> {'manager', 'o2o', 'department', 'analyst', 'strategy'}
# Tax Consulting - Indirect Tax (Global Trade) -> {'indirect', 'tax', 'consultant', 'global', 'trade'}
# Solution Consultant (Software Implementing and Consulting) -> {'implementing', 'solution', 'consultant', 'implement', 'software'}
# Head of Growth & Strategic Initiatives -> {'initiative', 'strategic', 'growth', 'head', 'initiatives'}
# Data Analytics - Digital Forensic (Senior Consultant - Manager) -> {'manager', 'analytics', 'consultant', 'forensic', 'analytic', 'digital', 'data'}
# Transport Safety Analysis Specialist -> {'transport', 'analyst', 'safety', 'specialist'}
# Management Consultant for HCM ( Engineer and Economics background) -> {'engineer', 'background', 'consultant', 'management', 'economics', 'economic', 'hcm'}
# SR&T : Consultant - M&A : Transaction Diligence, Execution & Rpt -> {'execution', 'rpt', 'sr&t', 'consultant', 'diligence', 'transaction', 'm&a'}
# Senior Management Consultant (Strategy) -> {'consultant', 'management', 'strategy'}
# Assistant Manager/ Manager (HR Organizational Development) -> {'manager', 'developer', 'organizational', 'assistant', 'hr'}
# Director - Company Secretary -> {'company', 'secretary', 'director'}
# ฺBusiness Consultant -> {'consultant', 'ฺbusiness'}
# Human Resources Business Partner -> {'resources', 'resource', 'human', 'business', 'partner'}
# Tax Consultant -> {'tax', 'consultant'}
# Business Strategy Development (data analysis) -> {'developer', 'analyst', 'data', 'business', 'datum', 'strategy'}
# Senior Presales (Solution Consultant) -> {'presale', 'presales', 'solution', 'consultant'}
# RaaS Consultant (mass recruitment) -> {'raas', 'mass', 'consultant', 'recruitment'}
# Senior Executive Manager - Market Intelligence -> {'executive', 'manager', 'intelligence', 'market'}
# Credit Risk Consultant (Associate - Senior) -> {'credit', 'consultant', 'risk', 'associate'}
# Market Risk Consultant (Associate - Senior) -> {'consultant', 'risk', 'associate', 'market'}
# Database Administrator (Oracle, PostgreSQL and MariaDB) -> {'mariadb', 'administration', 'oracle', 'database', 'postgresql'}
# Business Strategy Manager (Digital Marketing Agency) -> {'manager', 'marketing', 'agency', 'digital', 'business', 'strategy'}
# Head of Analytical Leads, Planning and Measurement -> {'planning', 'measurement', 'leads', 'analytical', 'head'}
# Risk Management Officer -> {'management', 'risk', 'officer'}
# Infrastructure Advisory - Consultant -> {'consultant', 'advisory', 'infrastructure'}
# Senior Officer/Specialist - System Analyst -> {'analyst', 'system', 'specialist', 'officer'}
# CRM Specialist  ( Data Analyst ) -> {'crm', 'specialist', 'analyst', 'data', 'datum'}
# Technical Product Consultant - Building System -> {'building', 'product', 'consultant', 'technical', 'system'}
# Investment Consultant (Manager -AVP Level) -> {'manager', 'investment', 'consultant', 'level', 'avp'}
# SAP Consultant -> {'consultant', 'sap'}
# System Consultant - PFSISTH MRT Phetburi -> {'phetburi', 'consultant', 'pfsisth', 'system', 'mrt'}
# Senior Application Consultant -> {'application', 'consultant'}
# Technical Support Expert (MEP Design  Background) -> {'background', 'expert', 'design', 'technical', 'mep', 'support'}
# MES Engineer/ Project Engineer/Pre-sales Engineer -> {'mes', 'sales', 'engineer', 'pre', 'project'}
# SR&T Senior Consultant - Strategy & Business Design - TH -> {'sr&t', 'consultant', 'design', 'th', 'business', 'strategy'}
# Business Analyst (Oracle EPM - Accounting / Financial consolidation) -> {'accounting', 'oracle', 'financial', 'epm', 'consolidation', 'analyst', 'business'}
# Technical Consultant (IT) / Software implementation -> {'technical', 'software', 'consultant', 'implementation'}
# SAP Consultant (FI, CO, SD, MM, HCM, BPC, DRC) -> {'co', 'consultant', 'sap', 'sd', 'drc', 'mm', 'bpc', 'hcm', 'fi'}
# IT Audit Consultant Manager -> {'manager', 'consultant', 'audit'}
# Project Cost Estimator / Marine Construction (32223) -> {'marine', '32223', 'cost', 'project', 'estimator', 'construction'}
# Business Analyst  (Oracle ERP) -> {'oracle', 'analyst', 'business', 'erp'}
# Pitch Team (Manager) -> {'manager', 'team', 'pitch'}
# Sale Quality Warranty -> {'quality', 'sale', 'warranty'}
# Business Development - Ads Specialist Account Management -> {'account', 'developer', 'ads', 'ad', 'specialist', 'management', 'business'}
# Service Consultant Engineer -> {'service', 'engineer', 'consultant'}
# Project Management Consultant (Senior) -> {'consultant', 'project', 'management'}
# Digital Solutions & Data Analytics -> {'analytics', 'solution', 'analytic', 'digital', 'data', 'solutions', 'datum'}
# Cloud Data Platform, Big Data, Datawarehouse, and BI Consultant -> {'cloud', 'datawarehouse', 'consultant', 'platform', 'big', 'data', 'bi', 'datum'}
# SEO & Content Specialist -> {'seo', 'specialist', 'content'}
# Trade Marketing Manager -> {'marketing', 'trade', 'manager'}
# HR Compliance Specialist -> {'compliance', 'specialist', 'hr'}
# Specialist, Security Governance Consultant -> {'security', 'specialist', 'consultant', 'governance'}
# SAP Consultant (All module) - for project implementation -> {'module', 'project', 'consultant', 'sap', 'implementation'}
# Business Consultant (For Data Management) -> {'management', 'consultant', 'data', 'business', 'datum'}
# Cybersecurity Consultant (Strategy, Governance, Risk, and Compliance) -> {'compliance', 'risk', 'consultant', 'governance', 'cybersecurity', 'strategy'}
# Senior Market Research Consultant -> {'research', 'consultant', 'market'}
# ERP Functional Consultant -> {'functional', 'erp', 'consultant'}
# Manager, Analytics & Insights (Bangkok-based, relocation provided) -> {'manager', 'analytics', 'provide', 'bangkok', 'based', 'base', 'insight', 'analytic', 'relocation', 'provided', 'insights'}
# Senior Manager, Supply Analytics (Bangkok-based role) -> {'manager', 'supply', 'analytics', 'bangkok', 'based', 'base', 'analytic', 'role'}
# Manager, Supply Optimization Analytics (Bangkok-based role) -> {'manager', 'supply', 'analytics', 'bangkok', 'based', 'base', 'analytic', 'optimization', 'role'}
# A&A: Manager – Senior Manager (Data Analytics for Auditing / IT Audit) -> {'manager', 'audit', 'analytics', 'a&a', 'analytic', 'auditing', 'data'}
# Senior Analytics Business Partner, People Analytics – Bangkok-Based -> {'people', 'analytics', 'bangkok', 'based', 'base', 'analytic', 'business', 'partner'}
# T&T Senior Consultant - Sales & Service (Salesforce Developer) - TH -> {'service', 't&t', 'sales', 'salesforce', 'developer', 'sale', 'consultant', 'th'}
# Senior Client Engagement (Sales IT, Data and AI) -> {'sales', 'intelligence', 'client', 'engagement', 'sale', 'artificial', 'data', 'datum'}
# Senior Manager- Fintech Data and Automation (Based in Bangkok, Relocation Provid -> {'manager', 'fintech', 'bangkok', 'based', 'base', 'automation', 'relocation', 'data', 'provid', 'datum'}
# Customer Segment Insights Manager (Urgent!) -> {'manager', 'segment', 'insight', 'urgent', 'customer', 'insights'}
# Cybersecurity Consultant -> {'cybersecurity', 'consultant'}
# Market Risk Consultant (Senior - Manager) -> {'manager', 'consultant', 'risk', 'market'}
# Credit Risk Consultant (Assistant Manager - Manager) -> {'credit', 'manager', 'assistant', 'consultant', 'risk'}
# T&T Consultant - Operations, Industry & Domain Solutions - TH -> {'t&t', 'operations', 'solution', 'domain', 'consultant', 'industry', 'th', 'solutions', 'operation'}
# A&A: Analyst - Consultant (Controls Assurance / GRC Specialist) -> {'assurance', 'consultant', 'specialist', 'controls', 'a&a', 'control', 'analyst', 'grc'}
# ERP Functional Consultant (Microsoft Dynamics 365)/ SCM Module -> {'microsoft', 'scm', 'module', 'dynamic', 'consultant', 'dynamics', 'functional', 'erp', '365'}
# T&T Consultant - SAP BTP (RPA) - TH -> {'t&t', 'rpa', 'consultant', 'sap', 'th', 'btp'}
# ERP Application Support/Consultant - Japanese speaking -> {'speaking', 'consultant', 'speak', 'application', 'erp', 'japanese', 'support'}
# T&T Senior Consultant - Penetration Tester - TH -> {'t&t', 'consultant', 'penetration', 'tester', 'th'}
# Officer (CSR and Compliance) (20K–30K) (SDG-122620) -> {'sdg', 'compliance', '122620', 'csr', 'officer', '20k–30k'}
# Policy & Compliance risks - GRC (Senior Consultant – Manager) -> {'manager', 'policy', 'compliance', 'risk', 'consultant', 'risks', 'grc'}
# ...
# ERP Programmer -> {'programmer', 'erp'}
# Back-end Developer (C#) -> {'end', 'c', 'developer'}
# Automate Tester (Playwright) -> {'automate', 'playwright', 'tester'}
# Full-stack Mobile Developer -> {'developer', 'stack', 'mobile'}
# Manager-Digital (Developer Lead) -> {'manager', 'developer', 'digital'}
# Full Stack Developer - Product Platform -> {'stack', 'product', 'developer', 'platform'}
# Software Engineer(Manufacturing) -> {'software', 'manufacturing', 'engineer'}
# .Net Developer (Bang Phli) -> {'bang', 'net', 'developer', 'phli'}
# IT Development Supervisor -> {'supervisor', 'developer'}
# Senior Full-Stack Developer -> {'stack', 'developer'}
# IT Operation -> {'operation'}
# Low Code Developer (Mendix) -> {'developer', 'mendix', 'low', 'code'}
# Tech Lead – Full Stack Developer & IT Operations Manager -> {'manager', 'developer', 'operations', 'tech', 'stack', 'operation'}
# Regional Strategic Brand Partnership Manager (Ads Solutions)-Bangkok -> {'manager', 'partnership', 'brand', 'bangkok', 'ad', 'regional', 'strategic', 'ads', 'solutions'}
# Software QA Automate -> {'quality', 'software', 'assurance', 'automate'}
# Senior Programmer -> {'programmer'}
# Automate Tester - Software Tester -> {'automate', 'software', 'tester'}
# Engineering Specialist IV -> {'engineer', 'specialist', 'iv'}
# IT System Engineer (Test Operations) -> {'engineer', 'operations', 'test', 'system', 'operation'}
# Junior Software Tester (Manual QA) – International working environment -> {'quality', 'assurance', 'manual', 'environment', 'working', 'software', 'international', 'tester'}
# Senior Programmer (1 Year Contract) -> {'1', 'programmer', 'year', 'contract'}
# Full Stack Developer (Core Banking) -> {'core', 'stack', 'developer', 'banking'}
# T&T Senior Consultant - Sales & Service (Technical Architect) - TH -> {'service', 't&t', 'sales', 'architect', 'sale', 'consultant', 'technical', 'th'}
# IT Engineer -> {'engineer'}
# Software Tester (Automate/Performance/Manual) -> {'automate', 'manual', 'performance', 'software', 'tester'}
# Specialist - Developer Full Stack (Direct experience in credit cards) -> {'credit', 'card', 'experience', 'developer', 'direct', 'specialist', 'cards', 'stack'}
# MES Engineer -> {'mes', 'engineer'}
# Assistant Manager – Sales Planning -> {'manager', 'planning', 'sales', 'assistant', 'sale'}
# Senior MES Engineer -> {'mes', 'engineer', 'me'}
# QA Engineer (IT Quality Assurance) -> {'quality', 'assurance', 'engineer'}
# Technical Project Manager -> {'technical', 'manager', 'project'}
# IT Application Specialist (ERP, D365 F&O) - Samut Prakan -> {'erp', 'prakan', 'specialist', 'd365', 'application', 'samut', 'f&o'}
# Full Stack Developer (Work From Everywhere) / 60,000 THB / Contract 6 months -> {'thb', 'developer', 'contract', '60', 'months', 'month', 'work', '6', '000', 'stack'}
# Software Support (WUEKRO) -> {'wuekro', 'software', 'support'}
# Web Engineer (Full Stack - Vue.js, Nuxt3) -> {'engineer', 'nuxt3', 'vue', 'stack', 'web', 'js'}
# Full Stack Developer (ประจำสำนักทะเบียนและประมวลผล) -> {'stack', 'developer', 'ประจำสำนักทะเบียนและประมวลผล'}
# Application Design (Retail Lending Solution) -> {'lending', 'solution', 'design', 'retail', 'application'}
# Full-Stack Engineer - BTS Ekkamai -  Salary up to 60 K (ID: 669134) -> {'engineer', 'bt', 'k', 'bts', '60', 'salary', 'd', '669134', 'stack', 'ekkamai'}
# Programmer (Contract) -> {'programmer', 'contract'}
# Executive Trainee (Retail Solution Development) -> {'developer', 'executive', 'solution', 'trainee', 'retail'}
# Software Developer (C# .NET) -> {'c', 'software', 'net', 'developer'}
# Java Developer (Pre-Test skills before interview session ) -> {'developer', 'pre', 'interview', 'skills', 'skill', 'session', 'java', 'test'}
# Digital Process Automation Engineer (Robotic Process Automation) -> {'engineer', 'process', 'digital', 'robotic', 'automation'}
# Software Developer (Hybrid) -> {'software', 'hybrid', 'developer'}
# Full-stack Software Development Manager -> {'manager', 'software', 'stack', 'developer'}
# Digital Operations Portfolio Project Manager -> {'manager', 'operations', 'project', 'portfolio', 'digital', 'operation'}
# Lead Developer of Private fund Project -> {'private', 'project', 'developer', 'fund'}
# Java Spring Boot -> {'spring', 'java', 'boot'}
# Back-End Developer -> {'end', 'developer'}
# Tech Lead, Digital Venture -> {'venture', 'tech', 'digital'}
# Product Owner - Warehouse Project -> {'warehouse', 'project', 'product', 'owner'}
# Full Stack Developer / Backend Developer -> {'stack', 'backend', 'developer'}
# Software Tester (Automate Test / Manual Test) -> {'automate', 'manual', 'test', 'software', 'tester'}
# Senior Officer, Business Development Department -> {'department', 'business', 'developer', 'officer'}
# Application Support (POS/ Application) -> {'application', 'pos', 'support'}
# Senior Engineer (Head Gimbal Assembly Mechanical Integration) -> {'engineer', 'mechanical', 'integration', 'gimbal', 'head', 'assembly'}
# Head of Technology Operations -> {'operations', 'operation', 'head', 'technology'}
# Full Stack Developer (with Low-Code/No-Code Expertise) -> {'expertise', 'developer', 'low', 'code', 'stack'}
# Project Manager (Digital Transformation) -> {'manager', 'transformation', 'project', 'digital'}
# Front-End Developer / Full-Stack Developer -> {'end', 'stack', 'developer'}
# Sales for Industrial IoT solution development -> {'sales', 'developer', 'solution', 'sale', 'industrial', 'iot'}
# Full Stack Web Developer (Contract 4 เดือน) -> {'contract', 'developer', '4', 'เดือน', 'stack', 'web'}
# Senior Software QA Engineer -> {'quality', 'software', 'assurance', 'engineer'}
# Software Developer (Web/Mobile/Back-End/Full Stack) -> {'developer', 'mobile', 'end', 'software', 'stack', 'web'}
# Junior Backend Developer -> {'developer', 'backend'}
# Fullstack Developer (C#.Net) -> {'net', 'fullstack', 'c#', 'developer'}
# Presales Software -> {'presale', 'presales', 'software'}
# Application Developer or Programmer (Senior) -> {'application', 'programmer', 'developer'}
# Information Technology Application Manager -> {'application', 'manager', 'information', 'technology'}
# Sr. Executive/ Asst Manager IT, TMS Solutions -> {'manager', 'asst', 'executive', 'solution', 'sr', 'solutions', 'tms'}
# IT Officer/IT Engineer -> {'engineer', 'officer'}
# Lead Software QA (Automation - Robot Framework), Makro Head Office -> {'quality', 'makro', 'assurance', 'robot', 'framework', 'software', 'automation', 'office', 'head'}
# Full Stack Developer (Golang, Node.js, / React.js) -> {'developer', 'react', 'node', 'golang', 'stack', 'js'}
# Senior Software QA (Automation - Robot Framework), Makro Head Office -> {'quality', 'makro', 'assurance', 'robot', 'framework', 'software', 'automation', 'office', 'head'}
# Full Stack Developer - Bang Kapi -> {'bang', 'kapi', 'stack', 'developer'}
# C# .NET Developer -> {'c', 'net', 'developer'}
# D365 F&O Technical Developer -> {'technical', 'developer', 'd365', 'f&o'}
# Automate Tester -> {'automate', 'tester'}
# Production Improve Staff (P) เจ้าหน้าที่ปรับปรุงระบบการผลิต -> {'staff', 'เจ้าหน้าที่ปรับปรุงระบบการผลิต', 'improve', 'production', 'p'}
# Programmer (ASP.NET MVC) -> {'programmer', 'net', 'mvc', 'asp'}
# Senior Quality Assurance Automation Engineer -> {'quality', 'assurance', 'engineer', 'automation'}
# Back-End API Developer -> {'end', 'developer', 'api'}
# Platform Operation Engineer -> {'engineer', 'operation', 'platform'}
# Manager - ICT (Head Office) -> {'manager', 'office', 'ict', 'head'}
# Senior AS400 & Cobol Support Developer -> {'as400', 'cobol', 'developer', 'support'}
# CIM Engineer (C#) - (Near BTS Bearing) -> {'engineer', 'bts', 'c', 'cim', 'bearing', 'near'}
# IT Auditor  (Welcome Fresh Graduate) -> {'graduate', 'auditor', 'welcome', 'fresh'}
# Application Support - Accounting / Senior Applicaiton Support-ERP (WFH 100%) -> {'100', 'accounting', 'wfh', 'application', 'applicaiton', 'erp', 'support'}
# Java Developer -> {'java', 'developer'}
# JAVA Developer -> {'java', 'developer'}
# Project Management Specialist (PM) -> {'specialist', 'project', 'management', 'pm'}
# Java Developer (Operation/Incident Support) -> {'developer', 'java', 'incident', 'operation', 'support'}
# JAVA Engineer – Junior to Mid Level -> {'engineer', 'java', 'mid', 'level'}
# R&D Engineer (IoT&Software embedded) -> {'r&d', 'engineer', 'embedded', 'embed', 'iot&software'}
# Golang Developer -> {'developer', 'golang'}
# Backend Developer (.Net Core, C#) -> {'core', 'developer', 'c', 'net', 'backend'}
# Principal/Senior Staff Product Test Engineering -> {'engineer', 'product', 'staff', 'principal', 'test'}
# Programmer (SAP) -> {'programmer', 'sap'}
# System Engineer - Digital Banking Team -> {'engineer', 'banking', 'team', 'digital', 'system'}
# .NET Developer ( .NET Framework / .NET Core) -> {'core', 'framework', 'net', 'developer'}
# Software developer -> {'software', 'developer'}
# Team Lead, Technical Product Support -> {'technical', 'team', 'product', 'support'}
# Expert Full Stack Developer -> {'stack', 'expert', 'developer'}
# Full Stack Developer (C#, Java/Kotlin/Python/JavaScript/TypeScript) -> {'developer', 'kotlin', 'c', 'javascript', 'typescript', 'java', 'stack', 'python'}
# Junior Back End Developer -> {'end', 'developer'}
# Senior Developer (Java) -> {'java', 'developer'}
# IT System Officer (Junior level/Welcome new graduates) -> {'graduate', 'officer', 'welcome', 'level', 'system', 'new', 'graduates'}
# Senior Full Stack Development Executive -> {'executive', 'stack', 'developer'}
# นักศึกษาฝึกงาน Power Apps Developer -> {'developer', 'app', 'นักศึกษาฝึกงาน', 'apps', 'power'}
# Principal Engineer, Development Engineering -> {'developer', 'engineer', 'principal'}
# Back End Developer - Java Springboot -> {'end', 'springboot', 'java', 'developer'}
# Manufacturing Test Engineer_90K_Si Racha Chonburi -> {'manufacturing', 'engineer', 'racha', '90k', 'chonburi', 'test', 'si'}
# Full Stack Developer (C#/.Net) -> {'net', 'stack', 'developer', 'c#'}
# Ant International-Senior Credit Risk Manager-Bettr -> {'credit', 'manager', 'international', 'risk', 'ant', 'bettr'}
# INTERN - ECONOMIC AFFAIRS (TRADE POLICY) -> {'affairs', 'policy', 'trade', 'economic', 'affair'}
# Fullstack Developer -> {'fullstack', 'developer'}
# Software Engineer - Dashboard -> {'software', 'engineer', 'dashboard'}
# TikTok Shop - TikTok Shop Governance Strategy Operation -> {'shop', 'strategy', 'tiktok', 'governance', 'operation'}
# TikTok Shop - Platform Campaign Analysis & Management - Integrated Marketing... -> {'shop', 'marketing', 'tiktok', 'management', 'platform', 'integrate', 'campaign', 'analyst', 'integrated'}
# TikTok Shop - Special Project (BI) - Thailand -> {'shop', 'thailand', 'project', 'tiktok', 'bi', 'special'}
# Software Engineering (Backend) -> {'software', 'engineer', 'backend'}
# Tech Functional Business Analyst (Senior) - Technology Consulting -> {'technology', 'consultant', 'analyst', 'functional', 'tech', 'business'}
# Program Manager / Project Manager – Learning and Talent Development (Bangkok bas -> {'manager', 'program', 'talent', 'developer', 'bas', 'bangkok', 'project', 'learn'}
# Senior Finance Accommodation Analyst (Bangkok based, relocation provided) -> {'provided', 'finance', 'provide', 'bangkok', 'based', 'base', 'relocation', 'analyst', 'accommodation'}
# Associate Director of Flights Marketing – Bangkok Based, Relocation Provided -> {'marketing', 'flights', 'provide', 'bangkok', 'based', 'base', 'flight', 'relocation', 'associate', 'provided', 'director'}
# Associate Director, Email and Communications Marketing (B2B Marketing) Bangkok -> {'marketing', 'b2b', 'bangkok', 'email', 'communications', 'associate', 'communication', 'director'}
# Associate Director of Communications Marketing (B2B Marketing) Bangkok Based -> {'marketing', 'b2b', 'bangkok', 'based', 'base', 'communications', 'associate', 'communication', 'director'}
# Project Manager/Associate Project Manager/Project Associate (analytics-focused -> {'manager', 'analytics', 'project', 'focus', 'focused', 'analytic', 'associate'}
# Business Owner – Supply Operations (Bangkok-based role) -> {'supply', 'bangkok', 'operations', 'based', 'base', 'owner', 'business', 'role', 'operation'}
# Product Operations Specialist (Flight) -> {'operations', 'product', 'specialist', 'flight', 'operation'}
# Manager/ Senior Manager, Strategic Partnerships – Travel Distribution -> {'manager', 'travel', 'partnership', 'strategic', 'partnerships', 'distribution'}
# Affiliate Manager, Strategic Partnerships – Bangkok-Based -> {'manager', 'partnership', 'bangkok', 'based', 'affiliate', 'base', 'strategic', 'partnerships'}
# TikTok Shop - Marketing Strategy & Project Lead (Thailand) -> {'shop', 'marketing', 'thailand', 'project', 'tiktok', 'strategy'}
# Specialist/Senior Specialist, Growth & Accelerator (Bangkok-based, Relocations -> {'relocations', 'accelerator', 'bangkok', 'based', 'base', 'specialist', 'relocation', 'growth'}
# NOC Manager (Bangkok-based, relocation provided) -> {'manager', 'noc', 'provide', 'bangkok', 'based', 'base', 'relocation', 'provided'}
# Associate Director / Senior Project Manager, Operational Excellence, Customer -> {'manager', 'project', 'excellence', 'associate', 'operational', 'customer', 'director'}
# Associate Director / Senior Project Manager, CX Projects, Customer Experience -> {'manager', 'experience', 'projects', 'project', 'cx', 'associate', 'customer', 'director'}
# Associate Director, CX Projects, Customer Experience Group -> {'experience', 'projects', 'project', 'cx', 'associate', 'customer', 'group', 'director'}
# Project Manager/Associate Project Manager (CX), Customer Experience Group -> {'manager', 'experience', 'project', 'cx', 'customer', 'group', 'associate'}
# Manager, Finance Innovations & Systems (Pay-in, Pay-out, GL, Tax), Based in Bkk -> {'manager', 'tax', 'innovations', 'finance', 'bkk', 'based', 'base', 'pay', 'gl', 'systems', 'innovation', 'system'}
# Director, Key Accounts (Global Chains management) (Bangkok based, Relocation -> {'account', 'bangkok', 'based', 'chains', 'base', 'management', 'global', 'director', 'chain', 'relocation', 'accounts', 'key'}
# Finance Manager/ Senior Manager -> {'manager', 'finance'}
# Admin officer (R&D Center team) -> {'r&d', 'center', 'officer', 'team', 'admin'}
# Business Development Director -> {'business', 'developer', 'director'}
# Buyer & Product Allocation Supervisor -> {'product', 'supervisor', 'buyer', 'allocation'}
# Accounting  & Finance Director -> {'director', 'accounting', 'finance'}
# Head of Marketing -> {'marketing', 'head'}
# Chief Finance Executive (CFO) - Thailand -> {'cfo', 'finance', 'executive', 'thailand', 'chief'}
# Business Development (Sales/Branch Innovation) -> {'branch', 'sales', 'developer', 'sale', 'innovation', 'business'}
# Sales Performance Trainer -> {'performance', 'sales', 'trainer', 'sale'}
# Corporate Finance Section Manager -> {'manager', 'section', 'corporate', 'finance'}
# Assistant Manager - Category management (Non Food & Dry Grocery Non Food) -> {'manager', 'food', 'dry', 'assistant', 'management', 'non', 'grocery', 'category'}
# Head of DC Project Management -> {'dc', 'project', 'management', 'head'}
# Senior Budgeting and Control Officer (Bang Na Office) -> {'bang', 'officer', 'na', 'budgeting', 'control', 'office'}
# Head of Online Content Management -> {'online', 'management', 'head', 'content'}
# Operational Risk Management (Junior Level) -> {'management', 'risk', 'level', 'operational'}
# Senior UX-UI Designer ประสบการณ์ 3-5 ปี ขอนแก่น -> {'5', '3', 'ประสบการณ์', 'designer', 'ปี', 'ขอนแก่น', 'ui', 'ux'}
# Senior Business Development (Financial Business) *** (ID: 669556) -> {'669556', 'developer', 'financial', 'd', 'business'}
# Business Administration Professional (Finance) -> {'business', 'administration', 'professional', 'finance'}
# Structuring -> {'structuring', 'structure'}
# Corporate Finance & Accounting Senior Specialist -> {'account', 'accounting', 'finance', 'specialist', 'corporate'}
# ADVANCED QUALITY ENGINEER -> {'quality', 'engineer', 'advanced'}
# Commercial Operations Manager, Vision Care Thailand -> {'manager', 'commercial', 'operations', 'thailand', 'vision', 'care', 'operation'}

# %%
combined_df["normalized_title"].value_counts()
# Out:
# normalized_title
# Unclassified                          4298
# data analyst                           637
# ai engineer                            401
# data engineer                          381
# data scientist                         309
# database engineer                       84
# machine learning engineer               69
# artificial intelligence specialist      67
# business intelligence analyst           58
# ai researcher                           46
# data architect                          45
# data product manager                    29
# sql developer                           29
# data visualization                      25
# analytics consultant                    12
# LLM / GenAI                             11
# sql engineer                             7
# ai strategist                            5
# data strategy consultant                 4
# computer vision specialist               3
# Name: count, dtype: int64

# %%
# Show only selected columns
preview_df = combined_df[["title", "search_keyword", "normalized_title"]]

# fix text wrapping, and display
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_rows", None)   # show all rows

# Peek at the first 20 rows
preview_df.head(100)
# Out:
#                                                                                title  \
# 0                                                                        AI Engineer
# 1                                        AI Engineer (Contract 1 Year) - EGG Digital
# 2                                                         AI Engineer (Pathum Thani)
# 3                                                                        AI Engineer
# 4                                                            Responsible AI Engineer
# 5                                                   Senior AI Engineer (EGG Digital)
# 6                            Machine Learning Engineer (Project Algorithmic Trading)
# 7                                                                        AI Engineer
# 8                                                AI Engineer (Innovation Department)
# 9                                                               AI Solutions Analyst
# 10                                                       Data Engineer (AI Engineer)
# 11                                                      Data Scientist (AI Engineer)
# 12                                                                    AI/ML Engineer
# 13                                                             Senior Data Scientist
# 14                                                           Chief AI Officer (CAIO)
# 15                  Data Scientist (AI on Digital Marketing & Hyper-Personalization)
# 16     Network Engineer or ML/AI Systems Architect Staff วิศวกรเครือข่าย สถาปนิกระบบ
# 17                                                              AI Software Engineer
# 18                                                  AI Integrator / AI Data Engineer
# 19                                     Senior Data Engineer (Generative AI Solution)
# 20                                                       AI/ML Specialist, Developer
# 21                                                     ExxonMobil IT Internship 2026
# 22                         AI Specialist/Lead (Innovation & Business Transformation)
# 23                                                      Data Engineer + Data Analyst
# 24                                           Department Manager, AI -  Data Engineer
# 25                                          Senior AI/ML Engineer (near Mega Bangna)
# 26                                              Business Improvement & AI Specialist
# 27                                                Internship Students - AI Developer
# 28                                          Business Intelligence Analyst (AI Focus)
# 29                                  Digital & AI Manager (Boon rawd Trading Company)
# 30                                                         Data Application Engineer
# 31              Data Partner - Business Writer- Thai Speakers (Global, Remote-Based)
# 32                                                        AI Product Owner Team Lead
# 33                                            AI Prompt Designer (English Expertise)
# 34                                                         Machine Learning Engineer
# 35                                              Artificial Intelligence Analyst (AI)
# 36                                     Senior Solution Delivery Engineer (Data & AI)
# 37                                                               Data Scientist - AI
# 38                   Digital Cloud & AI Solution Engineer – Innovative Data Platform
# 39            Technical Account Manager (Remote work)(Technology), Bangkok, Thailand
# 40                                                    Product Owner (Gen AI Product)
# 41                               Automated Quality Assurance Engineer (Mid - Senior)
# 42                         Cloud & AI Solution Engineer – Innovative AI Applications
# 43                                               SMT IE/AE Engineer - (Chachoengsao)
# 44                                                    Manager of Machine Learning/AI
# 45                                                                   Software Tester
# 46                                                      AI Transformation Specialist
# 47                                              Data Scientist (Mid to Senior Level)
# 48                                                                    Data Scientist
# 49                                                                    Data Scientist
# 50                                                                Pre-Sales Engineer
# 51                   Senior AI Developer (Edecation / IT / Up to 100 K (ID: 675915))
# 52                               Machine Learning Engineer (ML Engineer) Senior/Lead
# 53                               [Cooperative Internship 2025] MLOps Engineer Intern
# 54                  Senior Delivery Consultant - AI/ML , ASEAN Professional Services
# 55                                                          Data Scientist (On-Site)
# 56                                                             AI Specialist ( R&D )
# 57                                              AI Senior Software Developer (Silom)
# 58                                                                     AI Governance
# 59                                   IT-AI Programmer: Join Tungaloy-NTK in Chonburi
# 60            Data Scientist (Analytics AI / Application Developer) - Based in Korat
# 61                 MLOps Engineer – Bangkok-based (Full Relocation Package Provided)
# 62                                                                    Data Scientist
# 63                                                             Senior Data Scientist
# 64                                                               Presales Specialist
# 65                                                                          Presales
# 66                                                              AI & Tech Specialist
# 67                                                             Senior Data Scientist
# 68                                                                    Data Scientist
# 69                                                             Senior Tech Architect
# 70                                                     Tooling Software Sr. Engineer
# 71  Principal Software Engineer – (MLOPs) Machine Learning Operations (Bangkok based
# 72                       Lead DS (Data Scientist) Bangkok based, Relocation provided
# 73                                                                       AI engineer
# 74                                                      Senior Data Scientist and AI
# 75                                               DevOps Engineer  (Mid-level/Senior)
# 76                                       Senior Full Stack Engineer (Gen AI Startup)
# 77                                                  AI Software Engineer (Fullstack)
# 78                                                  Data Scientist (Innovation Team)
# 79                                                                       AI Prompter
# 80                                                                       AI Engineer
# 81                                                                       AI Engineer
# 82       AI Engineer Staff (Computer Vision + Embedded Deployment + Web Integration)
# 83                                             Senior Data Scientist & AI Specialist
# 84                                                                       AI Engineer
# 85                                 Senior Software Engineer, AI Model serving - Asia
# 86                                                                       AI Engineer
# 87                                                    Image Processing / ML Engineer
# 88                                                             Senior AI/ML Engineer
# 89                                                     AI Engineer (SAP Business AI)
# 90                                                                AI Agent Developer
# 91                                                  Senior Machine Learning Engineer
# 92                                           AI/ML Process Engineer II (Korat Plant)
# 93                                                                     AI Specialist
# 94                                        วิศวกรพัฒนาโซลูชัน Solution Engineer (IOT)
# 95                                                                          AI Coach
# 96                                                             Senior AI/ML Engineer
# 97                                                                    Data & AI Team
# 98                                                                  Python Developer
# 99                                                                      IoT Engineer
#
#    search_keyword                    normalized_title
# 0     ai engineer                         ai engineer
# 1     ai engineer                         ai engineer
# 2     ai engineer                         ai engineer
# 3     ai engineer                         ai engineer
# 4     ai engineer                         ai engineer
# 5     ai engineer                         ai engineer
# 6     ai engineer           machine learning engineer
# 7     ai engineer                         ai engineer
# 8     ai engineer                         ai engineer
# 9     ai engineer                        Unclassified
# 10    ai engineer                         ai engineer
# 11    ai engineer                         ai engineer
# 12    ai engineer                         ai engineer
# 13    ai engineer                      data scientist
# 14    ai engineer                        Unclassified
# 15    ai engineer                       ai researcher
# 16    ai engineer                         ai engineer
# 17    ai engineer                         ai engineer
# 18    ai engineer                         ai engineer
# 19    ai engineer                         ai engineer
# 20    ai engineer                         ai engineer
# 21    ai engineer                        Unclassified
# 22    ai engineer  artificial intelligence specialist
# 23    ai engineer                        data analyst
# 24    ai engineer                         ai engineer
# 25    ai engineer                         ai engineer
# 26    ai engineer  artificial intelligence specialist
# 27    ai engineer                         ai engineer
# 28    ai engineer       business intelligence analyst
# 29    ai engineer                        Unclassified
# 30    ai engineer                       data engineer
# 31    ai engineer                        Unclassified
# 32    ai engineer                        Unclassified
# 33    ai engineer                        Unclassified
# 34    ai engineer           machine learning engineer
# 35    ai engineer                        Unclassified
# 36    ai engineer                         ai engineer
# 37    ai engineer                       ai researcher
# 38    ai engineer                         ai engineer
# 39    ai engineer                        Unclassified
# 40    ai engineer                         LLM / GenAI
# 41    ai engineer                        Unclassified
# 42    ai engineer                         ai engineer
# 43    ai engineer                        Unclassified
# 44    ai engineer                        Unclassified
# 45    ai engineer                        Unclassified
# 46    ai engineer  artificial intelligence specialist
# 47    ai engineer                      data scientist
# 48    ai engineer                      data scientist
# 49    ai engineer                      data scientist
# 50    ai engineer                        Unclassified
# 51    ai engineer                         ai engineer
# 52    ai engineer           machine learning engineer
# 53    ai engineer           machine learning engineer
# 54    ai engineer                        Unclassified
# 55    ai engineer                      data scientist
# 56    ai engineer  artificial intelligence specialist
# 57    ai engineer                         ai engineer
# 58    ai engineer                       ai strategist
# 59    ai engineer                        Unclassified
# 60    ai engineer                         ai engineer
# 61    ai engineer           machine learning engineer
# 62    ai engineer                      data scientist
# 63    ai engineer                      data scientist
# 64    ai engineer                        Unclassified
# 65    ai engineer                        Unclassified
# 66    ai engineer  artificial intelligence specialist
# 67    ai engineer                      data scientist
# 68    ai engineer                      data scientist
# 69    ai engineer                        Unclassified
# 70    ai engineer                        Unclassified
# 71    ai engineer           machine learning engineer
# 72    ai engineer                      data scientist
# 73    ai engineer                         ai engineer
# 74    ai engineer                       ai researcher
# 75    ai engineer                        Unclassified
# 76    ai engineer                         ai engineer
# 77    ai engineer                         ai engineer
# 78    ai engineer                      data scientist
# 79    ai engineer                        Unclassified
# 80    ai engineer                         ai engineer
# 81    ai engineer                         ai engineer
# 82    ai engineer                         ai engineer
# 83    ai engineer                       ai researcher
# 84    ai engineer                         ai engineer
# 85    ai engineer                         ai engineer
# 86    ai engineer                         ai engineer
# 87    ai engineer           machine learning engineer
# 88    ai engineer                         ai engineer
# 89    ai engineer                         ai engineer
# 90    ai engineer                         ai engineer
# 91    ai engineer           machine learning engineer
# 92    ai engineer                         ai engineer
# 93    ai engineer  artificial intelligence specialist
# 94    ai engineer                        Unclassified
# 95    ai engineer                        Unclassified
# 96    ai engineer                         ai engineer
# 97    ai engineer                        Unclassified
# 98    ai engineer                        Unclassified
# 99    ai engineer                        Unclassified

# %%
# Show only selected columns
preview_df_unclassified = combined_df.loc[
    combined_df["normalized_title"] == "Unclassified",
    ["title", "search_keyword", "normalized_title"]
].drop_duplicates(subset=["title"])

# fix text wrapping, and display
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_rows", None)   # show all rows

preview_df_unclassified

preview_df_unclassified.to_csv(
    f"../data/jobstreet_{country}_unclassified.csv", 
    index=False,
    quotechar='"',
    escapechar='\\',
    encoding='utf-8-sig')
